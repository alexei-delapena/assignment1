# %%
#This code is to extract league statistics from the NBA's 30 teams, from the NBA API.

import pandas as pd
import matplotlib.pyplot as plt
import requests

HEADERS = {
    'Accept-Encoding': 'gzip, deflate, sdch',
    'Accept-Language': 'en-US,en;q=0.8',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'Referer': 'http://stats.nba.com/team/',
    'Connection': 'keep-alive',
    'x-nba-stats-origin': 'stats'
}

#This retrieves the headers and the rows from the JSON response.
def retrieve__data(url):
    response = requests.get(url, headers=HEADERS)
    while response.status_code != 200:
        response = requests.get(url)
        
    headers = response.json()['resultSets'][0]['headers']
    data = response.json()['resultSets'][0]['rowSet']
    data = pd.DataFrame(data, columns=headers)
    return data

#The utl 
url = 'http://stats.nba.com/stats/leaguedashteamstats?Conference=&DateFrom=&DateTo=&Division=&GameScope=&GameSegment=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&VsConference=&VsDivision='

# %%
data = retrieve_data(url)

#sorts the teams and statistics in terms of highest winning percentage.
results = data.sort_values(by=['W_PCT'], ascending=False)

print(results)
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  \
# 9   1610612744   Golden State Warriors  50  40  10  0.800  48.2  43.5  85.4
# 10  1610612745         Houston Rockets  47  34  13  0.723  48.2  39.2  85.3
# 1   1610612738          Boston Celtics  50  35  15  0.700  48.2  37.8  84.5
# 27  1610612761         Toronto Raptors  47  32  15  0.681  48.2  40.8  87.6
# 26  1610612759       San Antonio Spurs  51  32  19  0.627  48.0  38.0  83.7
# 17  1610612750  Minnesota Timberwolves  52  32  20  0.615  48.3  40.8  85.8
# 5   1610612739     Cleveland Cavaliers  47  28  19  0.596  48.1  39.6  83.6
# 20  1610612760   Oklahoma City Thunder  49  29  20  0.592  48.4  39.9  87.5
# 15  1610612748              Miami Heat  49  28  21  0.571  48.2  37.6  82.7
# 18  1610612740    New Orleans Pelicans  48  27  21  0.563  48.7  41.5  85.4
# 24  1610612757  Portland Trail Blazers  49  27  22  0.551  48.2  39.1  86.0
# 29  1610612764      Washington Wizards  49  27  22  0.551  48.3  39.9  85.7
# 11  1610612754          Indiana Pacers  50  27  23  0.540  48.2  41.3  86.0
# 22  1610612755      Philadelphia 76ers  45  24  21  0.533  48.4  39.9  85.8
# 16  1610612749         Milwaukee Bucks  47  25  22  0.532  48.2  39.0  81.2
# 7   1610612743          Denver Nuggets  49  26  23  0.531  48.3  39.4  85.7
# 12  1610612746             LA Clippers  48  24  24  0.500  48.1  39.1  84.4
# 8   1610612765         Detroit Pistons  47  22  25  0.468  48.1  38.7  86.2
# 19  1610612752         New York Knicks  50  22  28  0.440  48.5  40.5  85.8
# 28  1610612762               Utah Jazz  49  21  28  0.429  48.2  37.3  82.9
# 3   1610612766       Charlotte Hornets  48  20  28  0.417  48.2  38.1  86.6
# 13  1610612747      Los Angeles Lakers  48  19  29  0.396  48.7  40.8  89.4
# 4   1610612741           Chicago Bulls  49  18  31  0.367  48.7  39.1  88.8
# 2   1610612751           Brooklyn Nets  50  18  32  0.360  48.3  37.7  86.5
# 14  1610612763       Memphis Grizzlies  48  17  31  0.354  48.1  36.1  81.2
# 23  1610612756            Phoenix Suns  49  17  32  0.347  48.1  38.3  86.7
# 6   1610612742        Dallas Mavericks  50  16  34  0.320  48.2  37.9  84.6
# 25  1610612758        Sacramento Kings  48  15  33  0.313  48.1  38.3  84.8
# 21  1610612753           Orlando Magic  48  14  34  0.292  48.1  39.6  86.5
# 0   1610612737           Atlanta Hawks  49  14  35  0.286  48.1  38.4  85.3
#
#     FG_PCT           ...            TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 9    0.509           ...                  24        10         1          2
# 10   0.460           ...                  18         3        20         17
# 1    0.447           ...                  11        19        18          7
# 27   0.466           ...                   5         7         2         22
# 26   0.454           ...                   7        18         3          1
# 17   0.476           ...                   2         4        22         10
# 5    0.474           ...                  17        20        27          4
# 20   0.456           ...                  10         1        11          6
# 15   0.455           ...                  20        24         6         15
# 18   0.486           ...                  27        17         7          5
# 24   0.455           ...                  12        27         8         19
# 29   0.465           ...                  14        14        19         14
# 11   0.480           ...                   4        12        25         25
# 22   0.465           ...                  30         9         9         24
# 16   0.480           ...                   6         5        10          3
# 7    0.460           ...                  25        16        17         11
# 12   0.463           ...                  21        13        15         20
# 8    0.449           ...                   9        15        30         23
# 19   0.472           ...                  22        26         4         12
# 28   0.450           ...                  15         2        16          9
# 3    0.440           ...                   3        28        13         21
# 13   0.456           ...                  29         6        13         30
# 4    0.440           ...                   8        23        29         16
# 2    0.436           ...                  26        30        26         29
# 14   0.445           ...                  13        21         5         27
# 23   0.442           ...                  28        29        21         26
# 6    0.448           ...                   1        25        28          8
# 25   0.451           ...                  16         8        24         13
# 21   0.458           ...                  19        22        12         18
# 0    0.450           ...                  23        11        23         28
#
#     PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  CFID                CFPARAMS
# 9        12        26         1                1    10   Golden State Warriors
# 10       19        11         2                2    10         Houston Rockets
# 1        20        25        23                4    10          Boston Celtics
# 27       27        15         4                3    10         Toronto Raptors
# 26        1        22        27                6    10       San Antonio Spurs
# 17        2         5         6                7    10  Minnesota Timberwolves
# 5         5         6         5               15    10     Cleveland Cavaliers
# 20       18        14        13                5    10   Oklahoma City Thunder
# 15       16        24        28               20    10              Miami Heat
# 18       10         4         3               13    10    New Orleans Pelicans
# 24       14        23        20               10    10  Portland Trail Blazers
# 29       24         9         9                9    10      Washington Wizards
# 11        7        27        11               11    10          Indiana Pacers
# 22       30         8         7                8    10      Philadelphia 76ers
# 16       28        18        17               18    10         Milwaukee Bucks
# 7         3        16        12               12    10          Denver Nuggets
# 12       22         2         8               14    10             LA Clippers
# 8         6        29        24               17    10         Detroit Pistons
# 19       23        19        18               21    10         New York Knicks
# 28       11        20        26               19    10               Utah Jazz
# 3         4         1        14               16    10       Charlotte Hornets
# 13       25        13        10               24    10      Los Angeles Lakers
# 4         8        30        21               28    10           Chicago Bulls
# 2        21        12        15               25    10           Brooklyn Nets
# 14       29         7        29               23    10       Memphis Grizzlies
# 23       26         3        19               29    10            Phoenix Suns
# 6         9        17        25               22    10        Dallas Mavericks
# 25       15        28        30               30    10        Sacramento Kings
# 21       13        21        16               27    10           Orlando Magic
# 0        17         9        22               26    10           Atlanta Hawks
#
# [30 rows x 56 columns]

# %%
#Save the data into a csv file.
results.to_csv('league_standings.csv', index=False)
